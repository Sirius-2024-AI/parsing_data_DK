# %%
import pandas as pd
import numpy as np

# %%
cian_df = pd.read_csv(r'C:\Users\danii\domclick-parser\merged_data_cian.csv')

# %%
cian_df
# Out:
#       region                                            address     price  \
# 0      anapa  Краснодарский край, городской округ Город Анап...  10952600
# 1      anapa                              Анапа, ул Шевченко, 3  16890000
# 2      anapa  Краснодарский край, городской округ Город Анап...   9649380
# 3      anapa  Краснодарский край, Анапский район, Анапа г., ...   8700000
# 4      anapa  Краснодарский край, Анапа, Симферопольское шос...  15300000
# ...      ...                                                ...       ...
# 16191    spb  Санкт-Петербург, Пушкинский район, посёлок Шуш...   5791400
# 16192    spb         Санкт-Петербург, Колпино, Загородная улица   5845050
# 16193    spb            Санкт-Петербург, Октябрьская набережная   5805466
# 16194    spb                  Санкт-Петербург, Муринская дорога   5828800
# 16195    spb  г Санкт-Петербург, пр-кт Александровской Фермы...   5899999
#
#        total_area kitchen_area living_area  rooms_count  floor  floors_number  \
# ...

# %%
cian_df.columns #ЦИАН
# Out:
# Index(['region', 'address', 'price', 'total_area', 'kitchen_area',
#        'living_area', 'rooms_count', 'floor', 'floors_number', 'build_date',
#        'isСomplete', 'complitation_year', 'house_material', 'parking',
#        'decoration', 'balcony', 'longitude', 'latitude', 'passenger_elevator',
#        'cargo_elevator', 'metro', 'metro_distance', 'metro_transport',
#        'district', 'is_apartments', 'is_auction'],
#       dtype='object')

# %%
dk_df = pd.read_csv(r"C:\Users\danii\domclick-parser\with_metro.csv")

# %%
#dk_df

# %%
dk_df.columns #ДОМКЛИК
# Out:
# Index(['address', 'price', 'floor', 'total_floors', 'rooms', 'square', 'city',
#        'remont', 'balcon', 'uid', 'view', 'type_perec', 'lon', 'lat',
#        'metro_dist', 'metro_name'],
#       dtype='object')

# %%
dk_cols = ['address', 'price', 'floor', 'total_floors', 'rooms', 'square', 'city',
       'remont', 'balcon', 'uid', 'type_perec', 'lon', 'lat',
       'metro_dist', 'metro_name']

cian_cols = ['region', 'address', 'price', 'total_area', 'kitchen_area',
       'rooms_count', 'floor', 'floors_number', 'build_date',
       'house_material',
       'decoration', 'balcony', 'longitude', 'latitude',
       'metro', 'metro_distance', 'metro_transport',]

# %%
cian_df = cian_df[cian_cols]

# %%
#cian_df

# %%
dk_df = dk_df[dk_cols]

# %%
rename_dk = {'address':'address', 'price':'price', 'floor':'floor', 'total_floors':'total_floors',
             'rooms':'total_rooms', 'square':'area', 'city':'city',
             'remont':'remont', 'balcon':'total_balcony', 'uid':'uid', 'type_perec':'material_type',
             'lon':'longitude', 'lat':'latitude','metro_dist':'metro_dist_km', 'metro_name':'metro_name'}

# %%
dk_df.rename(columns=rename_dk, inplace=True)

# %%
dk_df['build_date'] = None

# %%
dk_df
# Out:
#                                 address       price  floor  total_floors  \
# 0                   Выборгская улица, 8  10680000.0    1.0           9.0
# 1                    улица Гурьянова, 9  12990000.0    3.0          12.0
# 2             Ленинградское шоссе, 13к2  10400000.0    5.0           5.0
# 3            Звенигородское шоссе, 3Ас1  12900000.0    3.0           9.0
# 4      Большая Черкизовская улица, 26к2  10300000.0    5.0           5.0
# ...                                 ...         ...    ...           ...
# 30436       проспект Непокорённых, 49к2  20500000.0    7.0          16.0
# 30437              Морской проспект, 33  98900000.0    2.0           7.0
# 30438       Ушаковская набережная, 3 к2  85000000.0   13.0          17.0
# 30439                 Кемская улица, 14  66500000.0    2.0           7.0
# 30440               Парадная улица, 3к2  79000000.0    6.0           8.0
#
#        total_rooms   area             city     remont  total_balcony  \
# ...

# %%
rename_cian = {'address':'address', 'price':'price', 'floor':'floor', 'floors_number':'total_floors',
             'rooms_count':'total_rooms', 'square':'area', 'region':'city',
             'decoration':'remont', 'balcony':'total_balcony', 'house_material':'material_type',
             'lon':'longitude', 'lat':'latitude','metro_distance':'metro_distance', 'metro':'metro_name',
             'build_date':'build_date', 'total_area': 'area'}

# %%
cian_df.rename(columns=rename_cian, inplace=True)
# Out:
# C:\Users\danii\AppData\Local\Temp\ipykernel_15012\1333600021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cian_df.rename(columns=rename_cian, inplace=True)

# %%
cian_df.columns
# Out:
# Index(['city', 'address', 'price', 'area', 'kitchen_area', 'total_rooms',
#        'floor', 'total_floors', 'build_date', 'material_type', 'remont',
#        'total_balcony', 'longitude', 'latitude', 'metro_name',
#        'metro_distance', 'metro_transport'],
#       dtype='object')

# %%
cian_df
# Out:
#         city                                            address     price  \
# 0      anapa  Краснодарский край, городской округ Город Анап...  10952600
# 1      anapa                              Анапа, ул Шевченко, 3  16890000
# 2      anapa  Краснодарский край, городской округ Город Анап...   9649380
# 3      anapa  Краснодарский край, Анапский район, Анапа г., ...   8700000
# 4      anapa  Краснодарский край, Анапа, Симферопольское шос...  15300000
# ...      ...                                                ...       ...
# 16191    spb  Санкт-Петербург, Пушкинский район, посёлок Шуш...   5791400
# 16192    spb         Санкт-Петербург, Колпино, Загородная улица   5845050
# 16193    spb            Санкт-Петербург, Октябрьская набережная   5805466
# 16194    spb                  Санкт-Петербург, Муринская дорога   5828800
# 16195    spb  г Санкт-Петербург, пр-кт Александровской Фермы...   5899999
#
#         area kitchen_area  total_rooms  floor  total_floors build_date  \
# ...

# %%
cian_df['metro_transport'] = cian_df['metro_transport'].str.split(',').str[0]
# Out:
# C:\Users\danii\AppData\Local\Temp\ipykernel_15012\3665627356.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cian_df['metro_transport'] = cian_df['metro_transport'].str.split(',').str[0]

# %%
cian_df
# Out:
#         city                                            address     price  \
# 0      anapa  Краснодарский край, городской округ Город Анап...  10952600
# 1      anapa                              Анапа, ул Шевченко, 3  16890000
# 2      anapa  Краснодарский край, городской округ Город Анап...   9649380
# 3      anapa  Краснодарский край, Анапский район, Анапа г., ...   8700000
# 4      anapa  Краснодарский край, Анапа, Симферопольское шос...  15300000
# ...      ...                                                ...       ...
# 16191    spb  Санкт-Петербург, Пушкинский район, посёлок Шуш...   5791400
# 16192    spb         Санкт-Петербург, Колпино, Загородная улица   5845050
# 16193    spb            Санкт-Петербург, Октябрьская набережная   5805466
# 16194    spb                  Санкт-Петербург, Муринская дорога   5828800
# 16195    spb  г Санкт-Петербург, пр-кт Александровской Фермы...   5899999
#
#         area kitchen_area  total_rooms  floor  total_floors build_date  \
# ...

# %%
cian_df['metro_distance'] = cian_df['metro_distance'].str.split(',').str[0]
# Out:
# C:\Users\danii\AppData\Local\Temp\ipykernel_15012\2447566494.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cian_df['metro_distance'] = cian_df['metro_distance'].str.split(',').str[0]

# %%
cian_df['metro_name'] = cian_df['metro_name'].str.split(',').str[0]
# Out:
# C:\Users\danii\AppData\Local\Temp\ipykernel_15012\179870817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cian_df['metro_name'] = cian_df['metro_name'].str.split(',').str[0]

# %%
cian_df = cian_df.drop(index = 5427)

# %%
cian_df.metro_transport.unique()
# Out:
# array([nan, 'transport', 'walk'], dtype=object)

# %%
cian_df[cian_df.metro_transport == "transport"].head(5)
# Out:
#             city                                            address     price  \
# 1227  balashikha  Московская область, Балашиха, микрорайон Желез...  10001090
# 1228  balashikha  Россия, Московская область, городской округ Ба...   6800000
# 1229  balashikha  Московская область, Балашиха, микрорайон Желез...   9826960
# 1230  balashikha   Московская область, Балашиха, улица Ситникова, 2   8500000
# 1231  balashikha  Московская область, Балашиха, микрорайон Желез...   9743125
#
#       area kitchen_area  total_rooms  floor  total_floors build_date  \
# 1227  64.9         16.9            3     10            18      empty
# 1228  43.0          7.0            2      3             9       1980
# 1229  57.2         15.5            2     17            17      empty
# 1230  50.6         20.5            1     11            17       2018
# 1231  59.5         16.4            2      2            17      empty
#
#      material_type remont total_balcony  longitude   latitude    metro_name  \
# ...

# %%
d_speed = {
    "walk": 90,
    "transport": 400
}

# %%
cian_df["metro_speed"] = cian_df["metro_transport"].apply(lambda x: d_speed.get(x, -1))

# %%
cian_df
# Out:
#         city                                            address     price  \
# 0      anapa  Краснодарский край, городской округ Город Анап...  10952600
# 1      anapa                              Анапа, ул Шевченко, 3  16890000
# 2      anapa  Краснодарский край, городской округ Город Анап...   9649380
# 3      anapa  Краснодарский край, Анапский район, Анапа г., ...   8700000
# 4      anapa  Краснодарский край, Анапа, Симферопольское шос...  15300000
# ...      ...                                                ...       ...
# 16191    spb  Санкт-Петербург, Пушкинский район, посёлок Шуш...   5791400
# 16192    spb         Санкт-Петербург, Колпино, Загородная улица   5845050
# 16193    spb            Санкт-Петербург, Октябрьская набережная   5805466
# 16194    spb                  Санкт-Петербург, Муринская дорога   5828800
# 16195    spb  г Санкт-Петербург, пр-кт Александровской Фермы...   5899999
#
#         area kitchen_area  total_rooms  floor  total_floors build_date  \
# ...

# %%
cian_df["metro_distance"] = cian_df["metro_distance"].fillna(0)

# %%
cian_df["metro_distance"].unique()
# Out:
# array([0, '9', '13', '11', '18', '17', '10', '15', '5', '19', '16', '8',
#        '14', '12', '6', '4', '20', '7', '3', '30', '22', '2', '24', '21',
#        '25', '1', '27', '26', '28', '23', '29', '40', '32'], dtype=object)

# %%
cian_df["metro_dist_km"] = cian_df["metro_speed"].astype(int) * cian_df["metro_distance"].astype(int) / 1000

# %%
cian_df.columns
# Out:
# Index(['city', 'address', 'price', 'area', 'kitchen_area', 'total_rooms',
#        'floor', 'total_floors', 'build_date', 'material_type', 'remont',
#        'total_balcony', 'longitude', 'latitude', 'metro_name',
#        'metro_distance', 'metro_transport', 'metro_speed', 'metro_dist_km'],
#       dtype='object')

# %%
dk_df.columns
# Out:
# Index(['address', 'price', 'floor', 'total_floors', 'total_rooms', 'area',
#        'city', 'remont', 'total_balcony', 'uid', 'material_type', 'longitude',
#        'latitude', 'metro_dist_km', 'metro_name', 'build_date'],
#       dtype='object')

# %%
cian_df = cian_df.drop(["metro_speed", "metro_transport", "metro_distance"], axis=1)

# %%
cian_df.columns
# Out:
# Index(['city', 'address', 'price', 'area', 'kitchen_area', 'total_rooms',
#        'floor', 'total_floors', 'build_date', 'material_type', 'remont',
#        'total_balcony', 'longitude', 'latitude', 'metro_name',
#        'metro_dist_km'],
#       dtype='object')

# %%
cian_df = cian_df[['city', 'address', 'price', 'area', 'kitchen_area', 'total_rooms',
       'floor', 'total_floors', 'build_date', 'material_type', 'remont',
       'total_balcony', 'metro_name',
       'metro_dist_km', 'longitude', 'latitude']]

# %%
cian_df
# Out:
#         city                                            address     price  \
# 0      anapa  Краснодарский край, городской округ Город Анап...  10952600
# 1      anapa                              Анапа, ул Шевченко, 3  16890000
# 2      anapa  Краснодарский край, городской округ Город Анап...   9649380
# 3      anapa  Краснодарский край, Анапский район, Анапа г., ...   8700000
# 4      anapa  Краснодарский край, Анапа, Симферопольское шос...  15300000
# ...      ...                                                ...       ...
# 16191    spb  Санкт-Петербург, Пушкинский район, посёлок Шуш...   5791400
# 16192    spb         Санкт-Петербург, Колпино, Загородная улица   5845050
# 16193    spb            Санкт-Петербург, Октябрьская набережная   5805466
# 16194    spb                  Санкт-Петербург, Муринская дорога   5828800
# 16195    spb  г Санкт-Петербург, пр-кт Александровской Фермы...   5899999
#
#         area kitchen_area  total_rooms  floor  total_floors build_date  \
# ...

# %%
dk_df.columns
# Out:
# Index(['address', 'price', 'floor', 'total_floors', 'total_rooms', 'area',
#        'city', 'remont', 'total_balcony', 'uid', 'material_type', 'longitude',
#        'latitude', 'metro_dist_km', 'metro_name', 'build_date'],
#       dtype='object')

# %%
dk_df = dk_df[['uid', 'city', 'address', 'price', 'area', 'total_rooms',
       'floor', 'total_floors', 'build_date', 'material_type', 'remont',
       'total_balcony', 'metro_name',
       'metro_dist_km', 'longitude', 'latitude']]
dk_df['kitchen_area'] = None
# Out:
# C:\Users\danii\AppData\Local\Temp\ipykernel_15012\3880574541.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dk_df['kitchen_area'] = None

# %%
dk_df
# Out:
#                 uid             city                           address  \
# 0      2.056866e+09           Москва               Выборгская улица, 8
# 1      2.058753e+09           Москва                улица Гурьянова, 9
# 2      2.056577e+09           Москва         Ленинградское шоссе, 13к2
# 3      2.060026e+09           Москва        Звенигородское шоссе, 3Ас1
# 4      2.060013e+09           Москва  Большая Черкизовская улица, 26к2
# ...             ...              ...                               ...
# 30436  1.870651e+09  Санкт-Петербург       проспект Непокорённых, 49к2
# 30437  1.525961e+09  Санкт-Петербург              Морской проспект, 33
# 30438  2.059036e+09  Санкт-Петербург       Ушаковская набережная, 3 к2
# 30439  1.633886e+09  Санкт-Петербург                 Кемская улица, 14
# 30440  2.056289e+09  Санкт-Петербург               Парадная улица, 3к2
#
#             price   area  total_rooms  floor  total_floors build_date  \
# ...

# %% [markdown]
# Checkpoint

# %%
dk_df.to_parquet("domclick_tmp_data.parquet")
cian_df.to_parquet("cian_tmp_data.parquet")

# %%
dk_df
# Out:
#                 uid             city                           address  \
# 0      2.056866e+09           Москва               Выборгская улица, 8
# 1      2.058753e+09           Москва                улица Гурьянова, 9
# 2      2.056577e+09           Москва         Ленинградское шоссе, 13к2
# 3      2.060026e+09           Москва        Звенигородское шоссе, 3Ас1
# 4      2.060013e+09           Москва  Большая Черкизовская улица, 26к2
# ...             ...              ...                               ...
# 30436  1.870651e+09  Санкт-Петербург       проспект Непокорённых, 49к2
# 30437  1.525961e+09  Санкт-Петербург              Морской проспект, 33
# 30438  2.059036e+09  Санкт-Петербург       Ушаковская набережная, 3 к2
# 30439  1.633886e+09  Санкт-Петербург                 Кемская улица, 14
# 30440  2.056289e+09  Санкт-Петербург               Парадная улица, 3к2
#
#             price   area  total_rooms  floor  total_floors build_date  \
# ...

# %%
cian_df
# Out:
#         city                                            address     price  \
# 0      anapa  Краснодарский край, городской округ Город Анап...  10952600
# 1      anapa                              Анапа, ул Шевченко, 3  16890000
# 2      anapa  Краснодарский край, городской округ Город Анап...   9649380
# 3      anapa  Краснодарский край, Анапский район, Анапа г., ...   8700000
# 4      anapa  Краснодарский край, Анапа, Симферопольское шос...  15300000
# ...      ...                                                ...       ...
# 16191    spb  Санкт-Петербург, Пушкинский район, посёлок Шуш...   5791400
# 16192    spb         Санкт-Петербург, Колпино, Загородная улица   5845050
# 16193    spb            Санкт-Петербург, Октябрьская набережная   5805466
# 16194    spb                  Санкт-Петербург, Муринская дорога   5828800
# 16195    spb  г Санкт-Петербург, пр-кт Александровской Фермы...   5899999
#
#         area kitchen_area  total_rooms  floor  total_floors build_date  \
# ...

# %%
dk_df["kitchen_area"] = dk_df["area"]*0.2
# Out:
# C:\Users\danii\AppData\Local\Temp\ipykernel_15012\2733474051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dk_df["kitchen_area"] = dk_df["area"]*0.2

# %%
dk_df
# Out:
#                 uid             city                           address  \
# 0      2.056866e+09           Москва               Выборгская улица, 8
# 1      2.058753e+09           Москва                улица Гурьянова, 9
# 2      2.056577e+09           Москва         Ленинградское шоссе, 13к2
# 3      2.060026e+09           Москва        Звенигородское шоссе, 3Ас1
# 4      2.060013e+09           Москва  Большая Черкизовская улица, 26к2
# ...             ...              ...                               ...
# 30436  1.870651e+09  Санкт-Петербург       проспект Непокорённых, 49к2
# 30437  1.525961e+09  Санкт-Петербург              Морской проспект, 33
# 30438  2.059036e+09  Санкт-Петербург       Ушаковская набережная, 3 к2
# 30439  1.633886e+09  Санкт-Петербург                 Кемская улица, 14
# 30440  2.056289e+09  Санкт-Петербург               Парадная улица, 3к2
#
#             price   area  total_rooms  floor  total_floors build_date  \
# ...

# %%
dk_df.to_parquet("domclick_checkpoint_data.parquet")
cian_df.to_parquet("cian_checkpoint_data.parquet")

# %%
year_df = pd.read_csv(r"C:\Users\danii\domclick-parser\tochno_final_100_procentov_42_pro_super_max_editional.csv")
# Out:
# C:\Users\danii\AppData\Local\Temp\ipykernel_15012\1413892428.py:1: DtypeWarning: Columns (11,12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   year_df = pd.read_csv(r"C:\Users\danii\domclick-parser\tochno_final_100_procentov_42_pro_super_max_editional.csv")

# %%
years = year_df[["uid", "year"]]
years = years.dropna()
years["uid"] = years.uid.astype(float)
dk_df["uid"] = dk_df.uid.astype(float)
# Out:
# C:\Users\danii\AppData\Local\Temp\ipykernel_15012\575043634.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dk_df["uid"] = dk_df.uid.astype(float)

# %%
dk_df
# Out:
#                 uid             city                           address  \
# 0      2.056866e+09           Москва               Выборгская улица, 8
# 1      2.058753e+09           Москва                улица Гурьянова, 9
# 2      2.056577e+09           Москва         Ленинградское шоссе, 13к2
# 3      2.060026e+09           Москва        Звенигородское шоссе, 3Ас1
# 4      2.060013e+09           Москва  Большая Черкизовская улица, 26к2
# ...             ...              ...                               ...
# 30436  1.870651e+09  Санкт-Петербург       проспект Непокорённых, 49к2
# 30437  1.525961e+09  Санкт-Петербург              Морской проспект, 33
# 30438  2.059036e+09  Санкт-Петербург       Ушаковская набережная, 3 к2
# 30439  1.633886e+09  Санкт-Петербург                 Кемская улица, 14
# 30440  2.056289e+09  Санкт-Петербург               Парадная улица, 3к2
#
#             price   area  total_rooms  floor  total_floors build_date  \
# ...

# %%
years
# Out:
#                 uid    year
# 16196  2.057140e+09  1982.0
# 16197  2.057613e+09  1962.0
# 16198  2.059627e+09  1989.0
# 16199  2.059957e+09  1998.0
# 16200  1.873373e+09  2004.0
# ...             ...     ...
# 53669  2.058298e+09  2013.0
# 53670  2.058651e+09  2008.0
# 53671  2.003169e+09  2012.0
# 53672  2.059619e+09  2012.0
# 53673  2.058885e+09     0.0
#
# [37478 rows x 2 columns]

# %%
dk_df[dk_df.uid.isin(years.uid)]
# Out:
#                 uid             city                      address       price  \
# 0      2.056866e+09           Москва          Выборгская улица, 8  10680000.0
# 1      2.058753e+09           Москва           улица Гурьянова, 9  12990000.0
# 2      2.056577e+09           Москва    Ленинградское шоссе, 13к2  10400000.0
# 7      1.950697e+09           Москва    улица Габричевского, 10к2  11500000.0
# 8      2.059491e+09           Москва        улица Менжинского, 21  13000000.0
# ...             ...              ...                          ...         ...
# 30436  1.870651e+09  Санкт-Петербург  проспект Непокорённых, 49к2  20500000.0
# 30437  1.525961e+09  Санкт-Петербург         Морской проспект, 33  98900000.0
# 30438  2.059036e+09  Санкт-Петербург  Ушаковская набережная, 3 к2  85000000.0
# 30439  1.633886e+09  Санкт-Петербург            Кемская улица, 14  66500000.0
# 30440  2.056289e+09  Санкт-Петербург          Парадная улица, 3к2  79000000.0
#
# ...

# %%
dk_df2 = pd.merge(dk_df, years, how="left", on=["uid"]).drop_duplicates()

# %%
dk_df2["build_date"] = dk_df2["year"]

# %%
dk_df2.drop("year", axis=1, inplace=True)

# %%
dk_df2
# Out:
#                 uid             city                           address  \
# 0      2.056866e+09           Москва               Выборгская улица, 8
# 2      2.058753e+09           Москва                улица Гурьянова, 9
# 4      2.056577e+09           Москва         Ленинградское шоссе, 13к2
# 6      2.060026e+09           Москва        Звенигородское шоссе, 3Ас1
# 7      2.060013e+09           Москва  Большая Черкизовская улица, 26к2
# ...             ...              ...                               ...
# 47662  2.059546e+09  Санкт-Петербург   улица Червонного Казачества, 26
# 47720  2.059449e+09  Санкт-Петербург       Свердловская набережная, 58
# 47727  1.979478e+09  Санкт-Петербург              улица Брянцева, 13к1
# 47734  1.912572e+09  Санкт-Петербург            9-я Советская улица, 5
# 47737  1.870651e+09  Санкт-Петербург       проспект Непокорённых, 49к2
#
#             price   area  total_rooms  floor  total_floors build_date  \
# ...

# %%
rdf = pd.concat([cian_df, dk_df2])

# %%
rdf.to_csv("result_df.csv", index=False)
